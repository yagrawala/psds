# %%
import util
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline

# %%
file_name = "../data/commit_timestamps/assorted.csv"
lines = [line.rstrip('\n') for line in open(file_name)]
lines = lines[1:]

# %%
ts = {}
for line in lines:
    val = line.split( "," )
    if val[0] in ts.keys():
        ts[ val[0] ].append( val[1] )
    else:
        ts[ val[0] ] = [ val[1] ]

# %%
for key in ts.keys():
    print( key, len( ts[key] ) )
# Out:
# ('d3/d3-dsv', 109)
# ('Microsoft/vscode-wordcount', 25)
# ('d3/d3-format', 302)
# ('d3/d3-timer', 127)
# ('d3/d3-random', 70)
# ('d3/d3-force', 218)
# ('Microsoft/vscode-textmate', 196)
# ('twbs/bootstrap-server', 39)
# ('d3/d3-xhr', 120)
# ('d3/d3-plugins', 653)
# ('apple/swift-protobuf', 1542)
# ('d3/d3-axis', 103)
# ('d3/d3-request', 120)
# ('d3/d3-ease', 134)
# ('twbs/bootstrap-rubygem', 1116)
# ('d3/d3-shape', 398)
# ('Microsoft/vscode-filewatcher-windows', 5)
# ('d3/d3-time', 169)
# ('apple/swift-corelibs-libdispatch', 914)
# ('Microsoft/vscode-htmltagwrap', 57)
# ('d3/d3-require', 65)
# ('d3/d3-time-format', 153)
# ('Microsoft/vscode-MDTools', 39)
# ('twbs/bootstrap', 17680)
# ('d3/d3-dispatch', 87)
# ('d3/d3-queue', 168)
# ('apple/swift-corelibs-foundation', 3477)
# ('apple/swift-package-manager', 3562)
# ('Microsoft/vscode-loader', 86)
# ('d3/d3-selection-multi', 48)
# ('Microsoft/vscode-spell-check', 89)
# ('tensorflow/tensorflow', 32316)
# ('d3/d3-quadtree', 158)
# ('Microsoft/vscode-mono-debug', 250)
# ('twbs/bootstrap-sass', 1009)
# ('Microsoft/vscode-jscs', 54)
# ('Microsoft/vscode-samples', 32)
# ('Microsoft/vscode-mock-debug', 196)
# ('Microsoft/vscode-editorconfig', 60)
# ('facebook/react-native-applinks', 8)
# ('d3/d3-polygon', 40)
# ('d3/d3-drag', 188)
# ('Microsoft/vscode-comment', 58)
# ('d3/d3-hierarchy', 345)
# ('apple/swift-corelibs-xctest', 444)
# ('d3/d3-array', 209)
# ('Microsoft/vscode', 32837)
# ('Microsoft/vscode-languageserver-node-example', 30)
# ('d3/d3-hexbin', 32)
# ('Microsoft/vscode-nls', 39)
# ('d3/d3-hull', 7)
# ('d3/d3-scale', 416)
# ('angular/angular.js', 8765)
# ('apple/swift', 69296)
# ('Microsoft/vscode-zoom', 6)
# ('facebook/react', 9828)
# ('Microsoft/vscode-htmlhint', 32)
# ('d3/d3', 4138)
# ('d3/d3-contour', 90)
# ('d3/d3-sankey', 61)
# ('d3/d3-chord', 43)
# ('Microsoft/vscode-backspace', 38)
# ('apple/swift-llbuild', 1296)
# ('d3/d3-collection', 41)
# ('cool-blue-d3/d3-fps', 5)
# ('d3/d3-transition', 287)
# ('d3/d3-arrays', 209)
# ('apple/swift-evolution', 2302)
# ('Microsoft/vscode-npm-scripts', 119)
# ('d3/d3-interpolate', 153)
# ('d3/d3-color', 169)
# ('d3/d3-bundler', 51)
# ('Intel-tensorflow/tensorflow', 32316)
# ('d3/d3-path', 57)

# %%
valid_keys = ["apple/swift", "d3/d3", "facebook/react",
              'tensorflow/tensorflow', 'twbs/bootstrap',
              'Microsoft/vscode', 'facebook/react',
              'angular/angular.js']
for key in valid_keys:
    print( key, len( ts[key] ) )
# Out:
# ('apple/swift', 69296)
# ('d3/d3', 4138)
# ('facebook/react', 9828)
# ('tensorflow/tensorflow', 32316)
# ('twbs/bootstrap', 17680)
# ('Microsoft/vscode', 32837)
# ('facebook/react', 9828)
# ('angular/angular.js', 8765)

# %%
FMT = "%Y-%m-%d"
ts_intvl_lst = {}
for key in valid_keys:
    temp_arr = []
    for i in range(1, len( ts[key] ) ):
        curr = ts[key][i].split(" ")[0]
        prev = ts[key][i-1].split(" ")[0]
        if curr == prev:
            continue
        diff = datetime.strptime(curr, FMT) - datetime.strptime(prev, FMT)
        temp_arr.append( diff.days )
    ts_intvl_lst[key] = temp_arr
# print( ts_intvl_lst )

# %%
plots = []
colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan']
counter = 1
for key in valid_keys:
    [c, ranges] = np.histogram( ts_intvl_lst[key], bins=range(1,100) )
    plot = util.getYPlotObj(c, "line", key, colors[counter])
    plots.append( plot )
    counter += 1
    util.plot_graph(range(1,99), plot, showLegend=True)

# %%
[c, ranges] = np.histogram( ts_intvl_lst['d3/d3'], bins=range(1,100) )
plot1 = util.getYPlotObj(c, "line", "X1", "red")
util.plot_graph(ranges[:-1], [plot1], showLegend=False)

# %%
[c, ranges] = np.histogram( ts_intvl_lst["facebook/react"], bins=range(1,100) )
plot1 = util.getYPlotObj(c, "line", "X1", "red")
util.plot_graph(ranges[:-1], [plot1], showLegend=False)

# %%
[c, ranges] = np.histogram( ts_intvl_lst["tensorflow/tensorflow"], bins=range(1,100) )
plot1 = util.getYPlotObj(c, "line", "X1", "red")
util.plot_graph(ranges[:-1], [plot1], showLegend=False)
